# %%
import pandas as pd
import glob

# %%
base_path = "/green-projects/project-urban_colocation_intelligence/workspace/share/data/"

files = glob.glob(base_path + "2025-03/*/*.gz") + \
        glob.glob(base_path + "2025-04/*/*.gz")

print("Files found:", len(files))
print(files[:5])
# Out:
# Files found: 1837
# ['/green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00000.gz', '/green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00001.gz', '/green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00002.gz', '/green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00003.gz', '/green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00004.gz']

# %%
files_sample = files[:60]

print("Using sample files:", len(files_sample))
# Out:
# Using sample files: 60

# %%
from collections import defaultdict
import pandas as pd

cols = ["id", "lat", "lon", "ts", "date", "h3", "type"]

home_counts = defaultdict(int)

for i, f in enumerate(files_sample):
    print(f"Loading {i+1}/{len(files_sample)}:", f)
    
    for chunk in pd.read_csv(
        f,
        sep="\t",             
        names=cols,            
        compression="gzip",
        chunksize=500000
    ):
        # keep only stops
        chunk = chunk[chunk["type"] == "stop"]

        # convert timestamp
        chunk["ts"] = pd.to_datetime(chunk["ts"], unit="s")
        chunk["hour"] = chunk["ts"].dt.hour

        # nighttime filter
        night_chunk = chunk[(chunk["hour"] >= 20) | (chunk["hour"] <= 6)]

        # group
        grouped = night_chunk.groupby(["id", "lat", "lon"]).size()

        # accumulate
        for key, val in grouped.items():
            home_counts[key] += val
# Out:
# Loading 1/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00000.gz
# Loading 2/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00001.gz
# Loading 3/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00002.gz
# Loading 4/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00003.gz
# Loading 5/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00004.gz
# Loading 6/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00005.gz
# Loading 7/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00006.gz
# Loading 8/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00007.gz
# Loading 9/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00008.gz
# Loading 10/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00009.gz
# Loading 11/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00010.gz
# Loading 12/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00011.gz
# Loading 13/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00012.gz
# Loading 14/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00013.gz
# Loading 15/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00014.gz
# Loading 16/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00015.gz
# Loading 17/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00016.gz
# Loading 18/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00017.gz
# Loading 19/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00018.gz
# Loading 20/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00019.gz
# Loading 21/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00020.gz
# Loading 22/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00021.gz
# Loading 23/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00022.gz
# Loading 24/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00023.gz
# Loading 25/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00024.gz
# Loading 26/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00025.gz
# Loading 27/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00026.gz
# Loading 28/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00027.gz
# Loading 29/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00028.gz
# Loading 30/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00029.gz
# Loading 31/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00030.gz
# Loading 32/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00031.gz
# Loading 33/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00032.gz
# Loading 34/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00033.gz
# Loading 35/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00034.gz
# Loading 36/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00035.gz
# Loading 37/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00037.gz
# Loading 38/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00036.gz
# Loading 39/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00038.gz
# Loading 40/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00039.gz
# Loading 41/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00040.gz
# Loading 42/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00041.gz
# Loading 43/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00042.gz
# Loading 44/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00043.gz
# Loading 45/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00044.gz
# Loading 46/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00045.gz
# Loading 47/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00046.gz
# Loading 48/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00047.gz
# Loading 49/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00048.gz
# Loading 50/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00049.gz
# Loading 51/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00050.gz
# Loading 52/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00051.gz
# Loading 53/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00052.gz
# Loading 54/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00053.gz
# Loading 55/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00054.gz
# Loading 56/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00055.gz
# Loading 57/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00056.gz
# Loading 58/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00057.gz
# Loading 59/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00058.gz
# Loading 60/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00059.gz

# %%
len(home_counts)
# Out:
# 33105395

# %%
import pandas as pd

# Step 1: convert dictionary → series (FAST)
s = pd.Series(home_counts)

# Step 2: convert to dataframe
home_df = s.reset_index()
home_df.columns = ["id", "lat", "lon", "count"]

print("Initial size:", len(home_df))

# Step 3: remove noise (VERY IMPORTANT for speed)
home_df = home_df[home_df["count"] >= 2]

print("After filtering:", len(home_df))

# Step 4: sort + get most frequent location per user
home_df = home_df.sort_values(["id", "count"], ascending=[True, False])
home_df = home_df.drop_duplicates("id")

# Step 5: rename
home_df = home_df.rename(columns={
    "lat": "home_lat",
    "lon": "home_lon"
})

# Step 6: keep only needed columns
home_df = home_df[["id", "home_lat", "home_lon"]]

# Step 7: FINAL CHECK (CRITICAL)
print(home_df[["home_lat", "home_lon"]].describe())
# Out:
# Initial size: 33105395
# After filtering: 788871
#             home_lat       home_lon
# count  687092.000000  687092.000000
# mean       52.642519      -1.446121
# std         1.443287       1.379196
# min        49.912600      -7.365660
# 25%        51.508179      -2.322700
# 50%        52.393613      -1.423600
# 75%        53.496900      -0.219900
# max        60.457570       1.751024

# %%
import numpy as np
import matplotlib.pyplot as plt

# Canary Wharf center
cw_lat, cw_lon = 51.505, -0.023

def haversine(lat1, lon1, lat2, lon2):
    R = 6371
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    a = np.sin(dlat/2)**2 + np.cos(lat1)*np.cos(lat2)*np.sin(dlon/2)**2
    return 2 * R * np.arcsin(np.sqrt(a))

# distance
home_df["distance_km"] = haversine(
    home_df["home_lat"],
    home_df["home_lon"],
    cw_lat,
    cw_lon
)

# %%
np.percentile(home_df["distance_km"], [50, 75, 90])
# Out:
# array([173.54020824, 273.43390828, 389.75438297])

# %%
plt.hist(home_df["distance_km"], bins=50)
plt.xlabel("Distance (km)")
plt.ylabel("Workers")
plt.title("Distance Distribution to Canary Wharf")
plt.show()

# %%
from collections import defaultdict
import pandas as pd

cols = ["id", "lat", "lon", "ts", "date", "h3", "type"]

home_counts = defaultdict(int)

df_list = []

for i, f in enumerate(files_sample):
    print(f"Reading {i+1}/{len(files_sample)}:", f)

    for chunk in pd.read_csv(
        f,
        sep="\t",
        names=cols,
        compression="gzip",
        chunksize=500000
    ):
        chunk = chunk[chunk["type"] == "stop"]

        # keep only required columns (IMPORTANT for speed)
        df_list.append(chunk[["id", "ts"]])
# Out:
# Reading 1/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00000.gz
# Reading 2/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00001.gz
# Reading 3/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00002.gz
# Reading 4/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00003.gz
# Reading 5/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00004.gz
# Reading 6/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00005.gz
# Reading 7/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00006.gz
# Reading 8/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00007.gz
# Reading 9/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00008.gz
# Reading 10/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00009.gz
# Reading 11/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00010.gz
# Reading 12/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00011.gz
# Reading 13/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00012.gz
# Reading 14/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00013.gz
# Reading 15/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00014.gz
# Reading 16/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00015.gz
# Reading 17/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00016.gz
# Reading 18/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00017.gz
# Reading 19/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00018.gz
# Reading 20/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00019.gz
# Reading 21/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00020.gz
# Reading 22/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00021.gz
# Reading 23/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00022.gz
# Reading 24/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00023.gz
# Reading 25/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00024.gz
# Reading 26/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00025.gz
# Reading 27/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00026.gz
# Reading 28/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00027.gz
# Reading 29/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00028.gz
# Reading 30/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00029.gz
# Reading 31/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00030.gz
# Reading 32/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00031.gz
# Reading 33/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00032.gz
# Reading 34/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00033.gz
# Reading 35/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00034.gz
# Reading 36/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00035.gz
# Reading 37/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00037.gz
# Reading 38/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00036.gz
# Reading 39/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00038.gz
# Reading 40/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00039.gz
# Reading 41/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00040.gz
# Reading 42/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00041.gz
# Reading 43/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00042.gz
# Reading 44/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00043.gz
# Reading 45/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00044.gz
# Reading 46/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00045.gz
# Reading 47/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00046.gz
# Reading 48/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00047.gz
# Reading 49/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00048.gz
# Reading 50/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00049.gz
# Reading 51/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00050.gz
# Reading 52/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00051.gz
# Reading 53/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00052.gz
# Reading 54/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00053.gz
# Reading 55/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00054.gz
# Reading 56/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00055.gz
# Reading 57/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00056.gz
# Reading 58/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00057.gz
# Reading 59/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00058.gz
# Reading 60/60: /green-projects/project-urban_colocation_intelligence/workspace/share/data/2025-03/3/part-00059.gz

# %%
df = pd.concat(df_list, ignore_index=True)

print("DF size:", len(df))
# Out:
# DF size: 82102364

# %%
np.percentile(home_df["distance_km"], [50, 75, 90])
# Out:
# array([173.54020824, 273.43390828, 389.75438297])

# %%
import pandas as pd
import numpy as np

percentiles = np.percentile(home_df["distance_km"], [50, 75, 90])

percentile_table = pd.DataFrame({
    "Metric": [
        "Median (50%)",
        "75th Percentile",
        "90th Percentile"
    ],
    "Distance (km)": percentiles
})

percentile_table
# Out:
#             Metric  Distance (km)
# 0     Median (50%)      20.475712
# 1  75th Percentile      46.124548
# 2  90th Percentile      66.665267

# %%
plt.hist(home_df["distance_km"], bins=50)
plt.xlabel("Distance (km)")
plt.ylabel("Workers")
plt.title("Distance Distribution to Canary Wharf")
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(home_df["distance_km"], bins=40, density=True)

plt.xlabel("Distance (km)")
plt.ylabel("Density")
plt.title("Distance Distribution to Canary Wharf")

plt.show()

# %%
# !pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in /wingrdp/homedirs/kb4850/.local/lib/python3.10/site-packages (0.20.0)
# Requirement already satisfied: numpy in /wingrdp/homedirs/kb4850/.local/lib/python3.10/site-packages (from folium) (2.2.6)
# Requirement already satisfied: xyzservices in /wingrdp/homedirs/kb4850/.local/lib/python3.10/site-packages (from folium) (2025.11.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/lib/python3/dist-packages (from folium) (3.0.3)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from folium) (2.25.1)
# Requirement already satisfied: branca>=0.6.0 in /wingrdp/homedirs/kb4850/.local/lib/python3.10/site-packages (from folium) (0.8.2)

# %%
import plotly.express as px

# sample for performance
sample_df = home_df.sample(5000, random_state=42)

# create map
fig = px.scatter_mapbox(
    sample_df,
    lat="home_lat",
    lon="home_lon",
    color="distance_km",
    color_continuous_scale="YlOrRd",
    zoom=9,
    height=600,
    title="Worker Commute Distance to Canary Wharf"
)

fig.update_layout(
    mapbox_style="open-street-map",
    margin={"r":0,"t":40,"l":0,"b":0}
)


fig.write_html("canary_wharf_map.html")

print("Saved as canary_wharf_map.html")
# Out:
# Saved as canary_wharf_map.html

# %%
import plotly.express as px

sample_df = home_df.sample(5000, random_state=42)

fig = px.scatter_mapbox(
    sample_df,
    lat="home_lat",
    lon="home_lon",
    color="distance_km",
    color_continuous_scale="YlOrRd",
    zoom=9,
    height=600,
    title="Worker Commute Distance to Canary Wharf"
)

fig.update_layout(
    mapbox_style="carto-positron",  
    margin={"r":0,"t":40,"l":0,"b":0}
)

fig.write_html("clean_map.html")

# %%
import plotly.express as px
import json

sample_df = home_df.sample(5000, random_state=42)

fig = px.scatter_mapbox(
    sample_df,
    lat="home_lat",
    lon="home_lon",
    color="distance_km",
    color_continuous_scale="YlOrRd",
    zoom=9,
    height=600,
    title="Worker Commute Distance to Canary Wharf"
)

# load boundary
with open("/green-projects/project-urban_colocation_intelligence/workspace/share/data/boundary/canary_wharf.geojson") as f:
    cw_geo = json.load(f)

fig.update_layout(
    mapbox=dict(
        style="carto-positron",
        layers=[
            {
                "source": cw_geo,
                "type": "line",
                "color": "blue",
                "line": {"width": 3},
            }
        ]
    ),
    margin={"r":0,"t":40,"l":0,"b":0}
)

fig.write_html("final_map.html")
